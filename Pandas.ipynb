# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\user\Downloads\Python Training\insurance.csv')
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# No. of rows and column
data.shape
# Out:
# (1338, 7)

# %%
# No. of rows in your dataframe
len(data)
# Out:
# 1338

# %%
data.head()
# top 5 rows are return in default
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.tail()
# last 5 rows in default
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
# descriptive statistics 
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# return for the position where there is null value
data.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
data.isnull().sum()
# total no. of null present
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data['age'].head()
# Out:
# 0    19
# 1    18
# 2    28
# 3    33
# 4    32
# Name: age, dtype: int64

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
data['age'].value_counts()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
data['region'].value_counts(normalize = True)*100
# Out:
# southeast    27.204783
# southwest    24.289985
# northwest    24.289985
# northeast    24.215247
# Name: region, dtype: float64

# %%
data['smoker'].value_counts(normalize = True)*100
# Out:
# no     79.521674
# yes    20.478326
# Name: smoker, dtype: float64

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data['age'].fillna('30')
# To fill Null/none/NA/Empty values with the value specify
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
print(data.dtypes, end = '\n\n') # To find the data types of all the columns

print(data.dtypes['age']) # to find data type of a specific cloumn
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object
#
# int64

# %%
data.info()
# Give info regarding data sets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
""" Rename a column => (inplace = True) is used to commit the new column name
 without it data will not be modified, only displayed"""
data.rename(columns = {'sex' : 'gender'}, inplace = True)

# %%
data.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data.head(1)
# Out:
#    age  gender   bmi  children smoker     region    charges
# 0   19  female  27.9         0    yes  southwest  16884.924

# %%
data.groupby(['region'])['charges'].mean()
# Region wise average charges
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
data.groupby(['smoker'])['charges'].mean()
# Smoker wise average charges
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
data.groupby(['smoker','gender'])['charges'].mean()
# Smoker wise and gender wise average charges
# Out:
# smoker  gender
# no      female     8762.297300
#         male       8087.204731
# yes     female    30678.996276
#         male      33042.005975
# Name: charges, dtype: float64

# %%
data.groupby(['smoker','gender'])['charges'].count().reset_index()
# Smoker wise and gender wise count of charges
# Out:
#   smoker  gender  charges
# 0     no  female      547
# 1     no    male      517
# 2    yes  female      115
# 3    yes    male      159

# %%
data.groupby(['smoker','region','gender'])['charges'].mean()
# Out:
# smoker  region     gender
# no      northeast  female     9640.426984
#                    male       8664.042222
#         northwest  female     8786.998679
#                    male       8320.689321
#         southeast  female     8440.205552
#                    male       7609.003587
#         southwest  female     8234.091260
#                    male       7778.905534
# yes     northeast  female    28032.046398
#                    male      30926.252583
#         northwest  female    29670.824946
#                    male      30713.181419
#         southeast  female    33034.820716
#                    male      36029.839367
#         southwest  female    31687.988430
#                    male      32598.862854
# Name: charges, dtype: float64

# %%
# Assign the o/p of groupby to a new df(dataframe)

data_smoker_gender = data.groupby(['smoker','region','gender'])['charges'].mean().reset_index()
print(type(data_smoker_gender))
data_smoker_gender
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    smoker     region  gender       charges
# 0      no  northeast  female   9640.426984
# 1      no  northeast    male   8664.042222
# 2      no  northwest  female   8786.998679
# 3      no  northwest    male   8320.689321
# 4      no  southeast  female   8440.205552
# 5      no  southeast    male   7609.003587
# 6      no  southwest  female   8234.091260
# 7      no  southwest    male   7778.905534
# 8     yes  northeast  female  28032.046398
# 9     yes  northeast    male  30926.252583
# 10    yes  northwest  female  29670.824946
# 11    yes  northwest    male  30713.181419
# 12    yes  southeast  female  33034.820716
# 13    yes  southeast    male  36029.839367
# 14    yes  southwest  female  31687.988430
# 15    yes  southwest    male  32598.862854

# %%
data['age'] = data['age'].astype('str')

# %%
data['age'][0]
# Out:
# '19'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   object
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 73.3+ KB

# %%
# sort_by
data.sort_values(by = ['charges']).head()
# Out:
#      age gender    bmi  children smoker     region    charges
# 940   18   male  23.21         0     no  southeast  1121.8739
# 808   18   male  30.14         0     no  southeast  1131.5066
# 1244  18   male  33.33         0     no  southeast  1135.9407
# 663   18   male  33.66         0     no  southeast  1136.3994
# 22    18   male  34.10         0     no  southeast  1137.0110

# %%
data.sort_values(by = ['charges'], ascending = False).head()
# Out:
#      age  gender     bmi  children smoker     region      charges
# 543   54  female  47.410         0    yes  southeast  63770.42801
# 1300  45    male  30.360         0    yes  southeast  62592.87309
# 1230  52    male  34.485         3    yes  northwest  60021.39897
# 577   31  female  38.095         1    yes  northeast  58571.07448
# 819   33  female  35.530         0    yes  northwest  55135.40209

# %%
data.sort_values(by = ['bmi']).head()
# Out:
#      age  gender     bmi  children smoker     region      charges
# 172   18    male  15.960         0     no  northeast   1694.79640
# 428   21  female  16.815         1     no  northeast   3167.45585
# 1226  38    male  16.815         2     no  northeast   6640.54485
# 412   26  female  17.195         2    yes  northeast  14455.64405
# 1286  28  female  17.290         0     no  northeast   3732.62510

# %%
new_col = []
for i in range(0,len(data)):
    new_col.append(i)

# %%
data['key'] = new_col

# %%
data.head()
# Out:
#   age  gender     bmi  children smoker     region      charges  key
# 0  19  female  27.900         0    yes  southwest  16884.92400    0
# 1  18    male  33.770         1     no  southeast   1725.55230    1
# 2  28    male  33.000         3     no  southeast   4449.46200    2
# 3  33    male  22.705         0     no  northwest  21984.47061    3
# 4  32    male  28.880         0     no  northwest   3866.85520    4

# %%
match = data[0:500].copy()

# %%
len(match)
# Out:
# 500

# %%
match.head()
# Out:
#   age  gender     bmi  children smoker     region      charges  key
# 0  19  female  27.900         0    yes  southwest  16884.92400    0
# 1  18    male  33.770         1     no  southeast   1725.55230    1
# 2  28    male  33.000         3     no  southeast   4449.46200    2
# 3  33    male  22.705         0     no  northwest  21984.47061    3
# 4  32    male  28.880         0     no  northwest   3866.85520    4

# %%
match.rename(columns = {'age' : 'Age','sex':'Gender','bmi':'BMI',\
                        'children':'Children','smoker':'Smoker','region':'Region',\
                       'charges':'Charges'}, inplace = True)

# %%
match.head()
# Out:
#   Age  gender     BMI  Children Smoker     Region      Charges  key
# 0  19  female  27.900         0    yes  southwest  16884.92400    0
# 1  18    male  33.770         1     no  southeast   1725.55230    1
# 2  28    male  33.000         3     no  southeast   4449.46200    2
# 3  33    male  22.705         0     no  northwest  21984.47061    3
# 4  32    male  28.880         0     no  northwest   3866.85520    4

# %%
# Joins => match df to data df
inner_join = pd.merge(data,match, how = 'inner')
inner_join.head()
# Out:
#   age  gender     bmi  children smoker     region      charges  key Age  \
# 0  19  female  27.900         0    yes  southwest  16884.92400    0  19
# 1  18    male  33.770         1     no  southeast   1725.55230    1  18
# 2  28    male  33.000         3     no  southeast   4449.46200    2  28
# 3  33    male  22.705         0     no  northwest  21984.47061    3  33
# 4  32    male  28.880         0     no  northwest   3866.85520    4  32
#
#       BMI  Children Smoker     Region      Charges
# 0  27.900         0    yes  southwest  16884.92400
# 1  33.770         1     no  southeast   1725.55230
# 2  33.000         3     no  southeast   4449.46200
# 3  22.705         0     no  northwest  21984.47061
# 4  28.880         0     no  northwest   3866.85520

# %%
len(inner_join)
# Out:
# 500

# %%
match.rename(columns = {'key':'primary'}, inplace = True)

# %%
match.columns
# Out:
# Index(['Age', 'gender', 'BMI', 'Children', 'Smoker', 'Region', 'Charges',
#        'primary'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region', 'charges',
#        'key'],
#       dtype='object')

# %%
# If column names are differnet
# If don't give (how = ) then it will use inner as a default
inner_df = pd.merge(data,match, how = 'inner', left_on = 'key', right_on = 'primary')

# %%
inner_df.head()
# Out:
#   age gender_x     bmi  children smoker     region      charges  key Age  \
# 0  19   female  27.900         0    yes  southwest  16884.92400    0  19
# 1  18     male  33.770         1     no  southeast   1725.55230    1  18
# 2  28     male  33.000         3     no  southeast   4449.46200    2  28
# 3  33     male  22.705         0     no  northwest  21984.47061    3  33
# 4  32     male  28.880         0     no  northwest   3866.85520    4  32
#
#   gender_y     BMI  Children Smoker     Region      Charges  primary
# 0   female  27.900         0    yes  southwest  16884.92400        0
# 1     male  33.770         1     no  southeast   1725.55230        1
# 2     male  33.000         3     no  southeast   4449.46200        2
# 3     male  22.705         0     no  northwest  21984.47061        3
# 4     male  28.880         0     no  northwest   3866.85520        4

# %%
left_df = pd.merge(data,match, how = 'left',\
                   left_on = 'key', right_on = 'primary')
left_df.head()
# Out:
#   age gender_x     bmi  children smoker     region      charges  key Age  \
# 0  19   female  27.900         0    yes  southwest  16884.92400    0  19
# 1  18     male  33.770         1     no  southeast   1725.55230    1  18
# 2  28     male  33.000         3     no  southeast   4449.46200    2  28
# 3  33     male  22.705         0     no  northwest  21984.47061    3  33
# 4  32     male  28.880         0     no  northwest   3866.85520    4  32
#
#   gender_y     BMI  Children Smoker     Region      Charges  primary
# 0   female  27.900       0.0    yes  southwest  16884.92400      0.0
# 1     male  33.770       1.0     no  southeast   1725.55230      1.0
# 2     male  33.000       3.0     no  southeast   4449.46200      2.0
# 3     male  22.705       0.0     no  northwest  21984.47061      3.0
# 4     male  28.880       0.0     no  northwest   3866.85520      4.0

# %%
len(left_df)
# Out:
# 1338

# %%
left_df.tail()
# Out:
#      age gender_x    bmi  children smoker     region     charges   key  Age  \
# 1333  50     male  30.97         3     no  northwest  10600.5483  1333  NaN
# 1334  18   female  31.92         0     no  northeast   2205.9808  1334  NaN
# 1335  18   female  36.85         0     no  southeast   1629.8335  1335  NaN
# 1336  21   female  25.80         0     no  southwest   2007.9450  1336  NaN
# 1337  61   female  29.07         0    yes  northwest  29141.3603  1337  NaN
#
#      gender_y  BMI  Children Smoker Region  Charges  primary
# 1333      NaN  NaN       NaN    NaN    NaN      NaN      NaN
# 1334      NaN  NaN       NaN    NaN    NaN      NaN      NaN
# 1335      NaN  NaN       NaN    NaN    NaN      NaN      NaN
# 1336      NaN  NaN       NaN    NaN    NaN      NaN      NaN
# 1337      NaN  NaN       NaN    NaN    NaN      NaN      NaN

# %%
right_df = pd.merge(data,match, how = 'right',\
                    left_on = 'key', right_on = 'primary')
right_df.head()
# Out:
#   age gender_x     bmi  children smoker     region      charges  key Age  \
# 0  19   female  27.900         0    yes  southwest  16884.92400    0  19
# 1  18     male  33.770         1     no  southeast   1725.55230    1  18
# 2  28     male  33.000         3     no  southeast   4449.46200    2  28
# 3  33     male  22.705         0     no  northwest  21984.47061    3  33
# 4  32     male  28.880         0     no  northwest   3866.85520    4  32
#
#   gender_y     BMI  Children Smoker     Region      Charges  primary
# 0   female  27.900         0    yes  southwest  16884.92400        0
# 1     male  33.770         1     no  southeast   1725.55230        1
# 2     male  33.000         3     no  southeast   4449.46200        2
# 3     male  22.705         0     no  northwest  21984.47061        3
# 4     male  28.880         0     no  northwest   3866.85520        4

# %%
len(right_df)
# Out:
# 500

# %%
left_df[left_df['primary'] == 0]
# Filtering the data frame for a particular condition
# Out:
#   age gender_x   bmi  children smoker     region    charges  key Age gender_y  \
# 0  19   female  27.9         0    yes  southwest  16884.924    0  19   female
#
#     BMI  Children Smoker     Region    Charges  primary
# 0  27.9       0.0    yes  southwest  16884.924      0.0

# %%
left_df[left_df['primary'] < 5][['region','charges']]
# Filtering the df for region and charges columns
# Out:
#       region      charges
# 0  southwest  16884.92400
# 1  southeast   1725.55230
# 2  southeast   4449.46200
# 3  northwest  21984.47061
# 4  northwest   3866.85520

# %%
# Concatenation

concat_df = pd.concat([data,match], ignore_index = True)
print(len(concat_df))
concat_df
# Out:
# 1838
#       age  gender     bmi  children smoker     region      charges  key  Age  \
# 0      19  female  27.900       0.0    yes  southwest  16884.92400  0.0  NaN
# 1      18    male  33.770       1.0     no  southeast   1725.55230  1.0  NaN
# 2      28    male  33.000       3.0     no  southeast   4449.46200  2.0  NaN
# 3      33    male  22.705       0.0     no  northwest  21984.47061  3.0  NaN
# 4      32    male  28.880       0.0     no  northwest   3866.85520  4.0  NaN
# ...   ...     ...     ...       ...    ...        ...          ...  ...  ...
# 1833  NaN    male     NaN       NaN    NaN        NaN          NaN  NaN   20
# 1834  NaN  female     NaN       NaN    NaN        NaN          NaN  NaN   31
# 1835  NaN    male     NaN       NaN    NaN        NaN          NaN  NaN   45
# 1836  NaN  female     NaN       NaN    NaN        NaN          NaN  NaN   44
# 1837  NaN  female     NaN       NaN    NaN        NaN          NaN  NaN   62
#
# ...

# %%
data.drop(columns = ['age','gender']).head()
# drop a column or a list of column
# Out:
#       bmi  children smoker     region      charges  key
# 0  27.900         0    yes  southwest  16884.92400    0
# 1  33.770         1     no  southeast   1725.55230    1
# 2  33.000         3     no  southeast   4449.46200    2
# 3  22.705         0     no  northwest  21984.47061    3
# 4  28.880         0     no  northwest   3866.85520    4

# %%
# apply/map
data['children'].apply(lambda x: x+1)
# Out:
# 0       1
# 1       2
# 2       4
# 3       1
# 4       1
#        ..
# 1333    4
# 1334    1
# 1335    1
# 1336    1
# 1337    1
# Name: children, Length: 1338, dtype: int64

# %%
data.head()
# Out:
#   age  gender     bmi  children smoker     region      charges  key
# 0  19  female  27.900         0    yes  southwest  16884.92400    0
# 1  18    male  33.770         1     no  southeast   1725.55230    1
# 2  28    male  33.000         3     no  southeast   4449.46200    2
# 3  33    male  22.705         0     no  northwest  21984.47061    3
# 4  32    male  28.880         0     no  northwest   3866.85520    4

# %%
data['gender'].apply(lambda x: 0 if x == 'female' else 1)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1333    1
# 1334    0
# 1335    0
# 1336    0
# 1337    0
# Name: gender, Length: 1338, dtype: int64

# %%
data.head(1)
# Out:
#   age  gender   bmi  children smoker     region    charges  key
# 0  19  female  27.9         0    yes  southwest  16884.924    0

# %%
data['gender'].map(lambda x: 0 if x == 'female' else 1)
# it will map output value on the bases of index, output of map and apply
# is same but prefer map instead of apply
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1333    1
# 1334    0
# 1335    0
# 1336    0
# 1337    0
# Name: gender, Length: 1338, dtype: int64

# %%
def update_gender (gend):
    if (gend == 'female'):
        return 0 
    else:
        return 1

# %%
data['gender'].map(lambda x: update_gender(x))
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1333    1
# 1334    0
# 1335    0
# 1336    0
# 1337    0
# Name: gender, Length: 1338, dtype: int64

# %%
data['gender']
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: gender, Length: 1338, dtype: object

# %%
data[data['gender'] == 'female']
# Out:
#      age  gender    bmi  children smoker     region      charges   key
# 0     19  female  27.90         0    yes  southwest  16884.92400     0
# 5     31  female  25.74         0     no  southeast   3756.62160     5
# 6     46  female  33.44         1     no  southeast   8240.58960     6
# 7     37  female  27.74         3     no  northwest   7281.50560     7
# 9     60  female  25.84         0     no  northwest  28923.13692     9
# ...   ..     ...    ...       ...    ...        ...          ...   ...
# 1332  52  female  44.70         3     no  southwest  11411.68500  1332
# 1334  18  female  31.92         0     no  northeast   2205.98080  1334
# 1335  18  female  36.85         0     no  southeast   1629.83350  1335
# 1336  21  female  25.80         0     no  southwest   2007.94500  1336
# 1337  61  female  29.07         0    yes  northwest  29141.36030  1337
#
# [662 rows x 8 columns]

# %%
import seaborn as sns

# %%
sns.countplot(x = 'gender', data = data, palette = 'Blues')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x = 'smoker', data = data, palette = 'Blues')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
import numpy as np

# %%
# Heatmap
# Correlation matrix => pearson coefficient(Linear regression)

# %%
a = np.array([[90,85,15],[75,5,25],[99,45,35]])
a
# Out:
# array([[90, 85, 15],
#        [75,  5, 25],
#        [99, 45, 35]])

# %%
sns.heatmap(a, annot = True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   object
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
#  7   key       1338 non-null   int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 83.8+ KB

# %%
data_smoker_gender
# Out:
#    smoker     region  gender       charges
# 0      no  northeast  female   9640.426984
# 1      no  northeast    male   8664.042222
# 2      no  northwest  female   8786.998679
# 3      no  northwest    male   8320.689321
# 4      no  southeast  female   8440.205552
# 5      no  southeast    male   7609.003587
# 6      no  southwest  female   8234.091260
# 7      no  southwest    male   7778.905534
# 8     yes  northeast  female  28032.046398
# 9     yes  northeast    male  30926.252583
# 10    yes  northwest  female  29670.824946
# 11    yes  northwest    male  30713.181419
# 12    yes  southeast  female  33034.820716
# 13    yes  southeast    male  36029.839367
# 14    yes  southwest  female  31687.988430
# 15    yes  southwest    male  32598.862854

# %%
data['smoker']
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: object

# %%
data['charges']
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64
